-- %%
SELECT * 
FROM orders_table;
-- Out:
-- StatementMeta(, 99ce106b-0583-4854-853e-6e2d7b9da3d7, 6, Finished, Available, Finished, False)
-- <Spark SQL result set with 1000 rows and 6 fields>

-- %%
SELECT * 
FROM orders_table
LIMIT 10;
-- Out:
-- StatementMeta(, 99ce106b-0583-4854-853e-6e2d7b9da3d7, 5, Finished, Available, Finished, False)
-- <Spark SQL result set with 10 rows and 6 fields>
